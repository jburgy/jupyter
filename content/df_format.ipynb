# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/jburgy/blog/blob/master/notebooks/DataFrame%20Formatting.ipynb)

# %%
import numpy as np
import pandas as pd
from colorsys import rgb_to_hls
from matplotlib import colormaps, colors

colormaps.register(
    name="RdWhGn",
    cmap=colors.LinearSegmentedColormap.from_list(
        "RdWhGn",
        ["#d65f5f", "#ffffff", "#5fba7d"],
    ))


def centered_background_gradient(
    v,
    cmap="PuBu",
    low=0,
    high=0,
    text_color_threshold=0.408,
    vmin=None,
    vmax=None,
):
    colors = colormaps[cmap]([0, 0.5, 1])
    nh, nl, ns = rgb_to_hls(*colors[0, :3])
    ph, pl, ps = rgb_to_hls(*colors[2, :3])
    smin = v.min() if vmin is None else vmin
    smax = v.max() if vmax is None else vmax
    bg = pd.DataFrame(dict(
        h=np.where(v < 0, nh, ph) * 360,
        s=np.where(v < 0, ns, ps),
        l=np.where(v < 0, (nl - 1) * v / smin + 1, (pl - 1) * v / smax + 1),
    ), index=v.index)
    return [
        f"background-color: hsl({r.h:.2f}, {r.s:.2%}, {r.l:.2%});"
        for r in bg.itertuples()
    ]

# %%
pd.DataFrame(np.transpose([
    [0.330, 4.87, 5.97, 0.073, 0.642, 1898, 568, 86.8, 102, 0.0146],
    [4879, 12104, 12756, 3475, 6792, 142984, 120536, 51118, 49528, 2370],
    [5427, 5243, 5514, 3340, 3933, 1326, 687, 1271, 1638, 2095],
    [3.7, 8.9, 9.8, 1.6, 3.7, 23.1, 9.0, 8.7, 11.0, 0.7],
    [4222.6, 2802.0, 24.0, 708.7, 24.7, 9.9, 10.7, 17.2, 16.1, 153.3],
    [57.9, 108.2, 149.6, 0.384, 227.9, 778.6, 1433.5, 2872.5, 4495.1, 5906.4],
    [167, 464, 15, -20, -65, -110, -140, -195, -200, -225],
    [0, 0, 1, 0, 2, 79, 82, 27, 14, 5],
]), index=pd.MultiIndex.from_tuples([
    ("Terrestial", "Mercury"),
    ("Terrestial", "Venus"),
    ("Terrestial", "Earth"),
    ("Terrestial", "Moon"),
    ("Terrestial", "Mars"),
    ("Jovian", "Jupiter"),
    ("Jovian", "Saturn"),
    ("Jovian", "Uranus"),
    ("Jovian", "Neptune"),
    ("Dwarf", "Pluto"),
], names=["Type", "Name"]), columns=[
    "Mass (10<sup>24</sup>kg)",
    "Diameter (km)",
    "Density (kg/m<sup>3</sup>)",
    "Gravity (m/s<sup>2</sup>)",
    "Length of day (hours)",
    "Distance from Sun (10<sup>6</sup>km)",
    "Mean temperature (°C)",
    "Number of moons",
]).style.format("{:0,.0f}").apply(centered_background_gradient, cmap="RdWhGn")
# Out:
# <style type="text/css">
# #T_ba41a_row0_col0 {
#   background-color: hsl(139.78, 39.74%, 99.99%);
# }
# #T_ba41a_row0_col1 {
#   background-color: hsl(139.78, 39.74%, 98.47%);
# }
# #T_ba41a_row0_col2 {
#   background-color: hsl(139.78, 39.74%, 55.81%);
# }
# #T_ba41a_row0_col3, #T_ba41a_row4_col3 {
#   background-color: hsl(139.78, 39.74%, 92.81%);
# }
# #T_ba41a_row0_col4, #T_ba41a_row1_col6, #T_ba41a_row2_col2, #T_ba41a_row5_col0, #T_ba41a_row5_col1, #T_ba41a_row5_col3, #T_ba41a_row6_col7, #T_ba41a_row9_col5 {
#   background-color: hsl(139.78, 39.74%, 55.10%);
# }
# #T_ba41a_row0_col5 {
#   background-color: hsl(139.78, 39.74%, 99.56%);
# }
# #T_ba41a_row0_col6 {
#   background-color: hsl(139.78, 39.74%, 83.84%);
# }
# #T_ba41a_row0_col7, #T_ba41a_row1_col7, #T_ba41a_row3_col0, #T_ba41a_row3_col5, #T_ba41a_row3_col7, #T_ba41a_row9_col0 {
#   background-color: hsl(139.78, 39.74%, 100.00%);
# }
# #T_ba41a_row1_col0 {
#   background-color: hsl(139.78, 39.74%, 99.88%);
# }
# #T_ba41a_row1_col1 {
#   background-color: hsl(139.78, 39.74%, 96.20%);
# }
# #T_ba41a_row1_col2 {
#   background-color: hsl(139.78, 39.74%, 57.30%);
# }
# #T_ba41a_row1_col3 {
#   background-color: hsl(139.78, 39.74%, 82.70%);
# }
# #T_ba41a_row1_col4 {
#   background-color: hsl(139.78, 39.74%, 70.20%);
# }
# #T_ba41a_row1_col5 {
#   background-color: hsl(139.78, 39.74%, 99.18%);
# }
# #T_ba41a_row2_col0 {
#   background-color: hsl(139.78, 39.74%, 99.86%);
# }
# #T_ba41a_row2_col1 {
#   background-color: hsl(139.78, 39.74%, 95.99%);
# }
# #T_ba41a_row2_col3 {
#   background-color: hsl(139.78, 39.74%, 80.95%);
# }
# #T_ba41a_row2_col4, #T_ba41a_row4_col4 {
#   background-color: hsl(139.78, 39.74%, 99.74%);
# }
# #T_ba41a_row2_col5 {
#   background-color: hsl(139.78, 39.74%, 98.86%);
# }
# #T_ba41a_row2_col6 {
#   background-color: hsl(139.78, 39.74%, 98.55%);
# }
# #T_ba41a_row2_col7 {
#   background-color: hsl(139.78, 39.74%, 99.45%);
# }
# #T_ba41a_row3_col1 {
#   background-color: hsl(139.78, 39.74%, 98.91%);
# }
# #T_ba41a_row3_col2 {
#   background-color: hsl(139.78, 39.74%, 72.80%);
# }
# #T_ba41a_row3_col3 {
#   background-color: hsl(139.78, 39.74%, 96.89%);
# }
# #T_ba41a_row3_col4 {
#   background-color: hsl(139.78, 39.74%, 92.46%);
# }
# #T_ba41a_row3_col6 {
#   background-color: hsl(0.00, 59.20%, 96.50%);
# }
# #T_ba41a_row4_col0 {
#   background-color: hsl(139.78, 39.74%, 99.98%);
# }
# #T_ba41a_row4_col1 {
#   background-color: hsl(139.78, 39.74%, 97.87%);
# }
# #T_ba41a_row4_col2 {
#   background-color: hsl(139.78, 39.74%, 67.97%);
# }
# #T_ba41a_row4_col5 {
#   background-color: hsl(139.78, 39.74%, 98.27%);
# }
# #T_ba41a_row4_col6 {
#   background-color: hsl(0.00, 59.20%, 88.61%);
# }
# #T_ba41a_row4_col7 {
#   background-color: hsl(139.78, 39.74%, 98.90%);
# }
# #T_ba41a_row5_col2 {
#   background-color: hsl(139.78, 39.74%, 89.20%);
# }
# #T_ba41a_row5_col4, #T_ba41a_row6_col4 {
#   background-color: hsl(139.78, 39.74%, 99.89%);
# }
# #T_ba41a_row5_col5 {
#   background-color: hsl(139.78, 39.74%, 94.08%);
# }
# #T_ba41a_row5_col6 {
#   background-color: hsl(0.00, 59.20%, 80.73%);
# }
# #T_ba41a_row5_col7 {
#   background-color: hsl(139.78, 39.74%, 56.74%);
# }
# #T_ba41a_row6_col0 {
#   background-color: hsl(139.78, 39.74%, 86.56%);
# }
# #T_ba41a_row6_col1 {
#   background-color: hsl(139.78, 39.74%, 62.15%);
# }
# #T_ba41a_row6_col2 {
#   background-color: hsl(139.78, 39.74%, 94.41%);
# }
# #T_ba41a_row6_col3 {
#   background-color: hsl(139.78, 39.74%, 82.51%);
# }
# #T_ba41a_row6_col5 {
#   background-color: hsl(139.78, 39.74%, 89.10%);
# }
# #T_ba41a_row6_col6 {
#   background-color: hsl(0.00, 59.20%, 75.48%);
# }
# #T_ba41a_row7_col0 {
#   background-color: hsl(139.78, 39.74%, 97.95%);
# }
# #T_ba41a_row7_col1 {
#   background-color: hsl(139.78, 39.74%, 83.95%);
# }
# #T_ba41a_row7_col2 {
#   background-color: hsl(139.78, 39.74%, 89.65%);
# }
# #T_ba41a_row7_col3 {
#   background-color: hsl(139.78, 39.74%, 83.09%);
# }
# #T_ba41a_row7_col4 {
#   background-color: hsl(139.78, 39.74%, 99.82%);
# }
# #T_ba41a_row7_col5 {
#   background-color: hsl(139.78, 39.74%, 78.16%);
# }
# #T_ba41a_row7_col6 {
#   background-color: hsl(0.00, 59.20%, 65.84%);
# }
# #T_ba41a_row7_col7 {
#   background-color: hsl(139.78, 39.74%, 85.22%);
# }
# #T_ba41a_row8_col0 {
#   background-color: hsl(139.78, 39.74%, 97.59%);
# }
# #T_ba41a_row8_col1 {
#   background-color: hsl(139.78, 39.74%, 84.45%);
# }
# #T_ba41a_row8_col2 {
#   background-color: hsl(139.78, 39.74%, 86.66%);
# }
# #T_ba41a_row8_col3 {
#   background-color: hsl(139.78, 39.74%, 78.62%);
# }
# #T_ba41a_row8_col4 {
#   background-color: hsl(139.78, 39.74%, 99.83%);
# }
# #T_ba41a_row8_col5 {
#   background-color: hsl(139.78, 39.74%, 65.83%);
# }
# #T_ba41a_row8_col6 {
#   background-color: hsl(0.00, 59.20%, 64.97%);
# }
# #T_ba41a_row8_col7 {
#   background-color: hsl(139.78, 39.74%, 92.33%);
# }
# #T_ba41a_row9_col1 {
#   background-color: hsl(139.78, 39.74%, 99.26%);
# }
# #T_ba41a_row9_col2 {
#   background-color: hsl(139.78, 39.74%, 82.94%);
# }
# #T_ba41a_row9_col3 {
#   background-color: hsl(139.78, 39.74%, 98.64%);
# }
# #T_ba41a_row9_col4 {
#   background-color: hsl(139.78, 39.74%, 98.37%);
# }
# #T_ba41a_row9_col6 {
#   background-color: hsl(0.00, 59.20%, 60.59%);
# }
# #T_ba41a_row9_col7 {
#   background-color: hsl(139.78, 39.74%, 97.26%);
# }
# </style>
# <table id="T_ba41a">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ba41a_level0_col0" class="col_heading level0 col0" >Mass (10<sup>24</sup>kg)</th>
#       <th id="T_ba41a_level0_col1" class="col_heading level0 col1" >Diameter (km)</th>
#       <th id="T_ba41a_level0_col2" class="col_heading level0 col2" >Density (kg/m<sup>3</sup>)</th>
#       <th id="T_ba41a_level0_col3" class="col_heading level0 col3" >Gravity (m/s<sup>2</sup>)</th>
#       <th id="T_ba41a_level0_col4" class="col_heading level0 col4" >Length of day (hours)</th>
#       <th id="T_ba41a_level0_col5" class="col_heading level0 col5" >Distance from Sun (10<sup>6</sup>km)</th>
#       <th id="T_ba41a_level0_col6" class="col_heading level0 col6" >Mean temperature (°C)</th>
#       <th id="T_ba41a_level0_col7" class="col_heading level0 col7" >Number of moons</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Type</th>
#       <th class="index_name level1" >Name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ba41a_level0_row0" class="row_heading level0 row0" rowspan="5">Terrestial</th>
#       <th id="T_ba41a_level1_row0" class="row_heading level1 row0" >Mercury</th>
#       <td id="T_ba41a_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_ba41a_row0_col1" class="data row0 col1" >4,879</td>
#       <td id="T_ba41a_row0_col2" class="data row0 col2" >5,427</td>
#       <td id="T_ba41a_row0_col3" class="data row0 col3" >4</td>
#       <td id="T_ba41a_row0_col4" class="data row0 col4" >4,223</td>
#       <td id="T_ba41a_row0_col5" class="data row0 col5" >58</td>
#       <td id="T_ba41a_row0_col6" class="data row0 col6" >167</td>
#       <td id="T_ba41a_row0_col7" class="data row0 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ba41a_level1_row1" class="row_heading level1 row1" >Venus</th>
#       <td id="T_ba41a_row1_col0" class="data row1 col0" >5</td>
#       <td id="T_ba41a_row1_col1" class="data row1 col1" >12,104</td>
#       <td id="T_ba41a_row1_col2" class="data row1 col2" >5,243</td>
#       <td id="T_ba41a_row1_col3" class="data row1 col3" >9</td>
#       <td id="T_ba41a_row1_col4" class="data row1 col4" >2,802</td>
#       <td id="T_ba41a_row1_col5" class="data row1 col5" >108</td>
#       <td id="T_ba41a_row1_col6" class="data row1 col6" >464</td>
#       <td id="T_ba41a_row1_col7" class="data row1 col7" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ba41a_level1_row2" class="row_heading level1 row2" >Earth</th>
#       <td id="T_ba41a_row2_col0" class="data row2 col0" >6</td>
#       <td id="T_ba41a_row2_col1" class="data row2 col1" >12,756</td>
#       <td id="T_ba41a_row2_col2" class="data row2 col2"
